# %%
from pathlib import Path
import os

workdir = Path("/Users/Anthony/Data and Analysis Local/NYS_Wetlands_GHG/")
os.chdir(workdir)
print(f"Current working directory: {Path.cwd()}")

# === CONFIGURATION ===
# Must match the output from NYS_03_create_patches_v2.ipynb
data_dir = Path("Data/Patches_v2")
cluster_id = 208  # Cluster to load, or None for legacy files
huc_id = None     # Specific HUC to load, or None to combine all HUCs in cluster

# Training hyperparameters
num_epochs = 25
batch_size = 10
learning_rate = 0.001
base_filters = 32  # U-Net base filter count

# Output directory for models
output_dir = Path("Models")
output_dir.mkdir(exist_ok=True)

print(f"\nData Configuration:")
print(f"  data_dir: {data_dir}")
print(f"  cluster_id: {cluster_id}")
print(f"  huc_id: {huc_id or 'All HUCs in cluster'}")
print(f"\nTraining Configuration:")
print(f"  num_epochs: {num_epochs}")
print(f"  batch_size: {batch_size}")
print(f"  learning_rate: {learning_rate}")
print(f"  base_filters: {base_filters}")
print(f"  output_dir: {output_dir}")
# Out:
# Current working directory: /Users/Anthony/Data and Analysis Local/NYS_Wetlands_GHG
#
# Data Configuration:
#   data_dir: Data/Patches_v2
#   cluster_id: 208
#   huc_id: All HUCs in cluster
#
# Training Configuration:
#   num_epochs: 25
#   batch_size: 10
#   learning_rate: 0.001
#   base_filters: 32
#   output_dir: Models

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import json
import time
import sys

# Add script directory to Python path
script_dir = Path("Python_Code_Analysis/DL_Implement/")
sys.path.insert(0, str(script_dir))

# Import modules
from NYS_04_dataset import get_dataloaders, find_patch_files, load_and_merge_metadata
from NYS_05_unet_model import UNet

# === LOAD DATA ===
print("Loading data...")
train_loader, val_loader, metadata = get_dataloaders(
    data_dir, 
    cluster_id=cluster_id, 
    huc_id=huc_id, 
    batch_size=batch_size
)

print(f"\nDataset Summary:")
print(f"  Training batches: {len(train_loader)}")
print(f"  Validation batches: {len(val_loader)}")
print(f"  in_channels: {metadata['in_channels']}")
print(f"  num_classes: {metadata['num_classes']}")
print(f"  band_names: {metadata['band_names']}")
if "hucs_included" in metadata:
    print(f"  HUCs included: {metadata['hucs_included']}")
# Out:
# Loading data...
# Found 9 training file(s)
# Found 9 validation file(s)
#
# Dataset Summary:
#   Training batches: 264
#   Validation batches: 67
#   in_channels: 11
#   num_classes: 5
#   band_names: ['r', 'g', 'b', 'nir', 'ndvi', 'ndwi', 'dem', 'chm', 'slope_5m', 'TPI_5m', 'Geomorph_5m']
#   HUCs included: ['metadata', '041402011002', 'metadata', '041402011004', 'metadata', 'metadata', 'metadata', 'metadata', 'metadata', 'metadata', 'metadata']

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device):
    """Train for one epoch and return average loss."""
    model.train()
    running_loss = 0.0

    for batch_idx, (X, y) in enumerate(train_loader):
        X, y = X.to(device), y.to(device)

        # Forward pass
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)

        # Backward pass
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Progress update every 10 batches
        if (batch_idx + 1) % 10 == 0:
            print(f"    Batch {batch_idx + 1}/{len(train_loader)}, Loss: {loss.item():.4f}")

    return running_loss / len(train_loader)


def validate(model, val_loader, criterion, device, metadata):
    """Validate and return loss plus per-class accuracy."""
    model.eval()
    running_loss = 0.0
    num_classes = metadata["num_classes"]
    class_names = metadata["class_names"]

    # Track correct predictions per class
    correct_per_class = torch.zeros(num_classes)
    total_per_class = torch.zeros(num_classes)

    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)

            outputs = model(X)
            loss = criterion(outputs, y)
            running_loss += loss.item()

            # Get predictions
            preds = torch.argmax(outputs, dim=1)

            # Per-class accuracy
            for c in range(num_classes):
                mask = (y == c)
                total_per_class[c] += mask.sum().item()
                correct_per_class[c] += ((preds == c) & mask).sum().item()

    avg_loss = running_loss / len(val_loader)

    # Calculate per-class accuracy
    class_acc = {}
    for c in range(num_classes):
        if total_per_class[c] > 0:
            class_acc[class_names[c]] = correct_per_class[c] / total_per_class[c]
        else:
            class_acc[class_names[c]] = 0.0

    # Overall accuracy
    overall_acc = correct_per_class.sum() / total_per_class.sum()

    return avg_loss, overall_acc.item(), class_acc

# %%
def compute_class_weights(data_dir, cluster_id, huc_id, class_names):
    """Compute class weights from training data using inverse frequency."""
    files = find_patch_files(data_dir, cluster_id, huc_id)
    
    print("Loading y_train files for class weight computation...")
    y_train_list = [np.load(f) for f in files['y_train']]
    y_train = np.concatenate(y_train_list, axis=0)
    print(f"  Combined y_train shape: {y_train.shape}")
    
    # Count pixels per class
    classes, counts = np.unique(y_train, return_counts=True)
    total = counts.sum()
    
    # Compute inverse frequency weights
    frequencies = counts / total
    weights = 1.0 / frequencies
    weights = weights / weights.min()  # Normalize so smallest weight is 1.0
    
    print("\nClass distribution and weights:")
    for c, count, w in zip(classes, counts, weights):
        pct = count / total * 100
        print(f"  {class_names[c]}: {count:,} pixels ({pct:.2f}%) -> weight: {w:.2f}")
    
    return torch.tensor(weights, dtype=torch.float32)


def main():
    # Device selection
    device = torch.device("cuda" if torch.cuda.is_available() else 
                          "mps" if torch.backends.mps.is_available() else "cpu")
    print(f"Using device: {device}")

    # === COMPUTE CLASS WEIGHTS ===
    class_weights = compute_class_weights(
        data_dir, cluster_id, huc_id, metadata["class_names"]
    )

    # === CREATE MODEL ===
    print("\nInitializing model...")
    model = UNet(
        in_channels=metadata["in_channels"],
        num_classes=metadata["num_classes"],
        base_filters=base_filters
    )
    model = model.to(device)
    
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Total parameters: {total_params:,}")

    # === LOSS AND OPTIMIZER ===
    class_weights = class_weights.to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # === TRAINING LOOP ===
    print("\nStarting training...")
    print("=" * 60)

    best_val_loss = float('inf')
    history = {'train_loss': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        epoch_start = time.time()
        print(f"\nEpoch {epoch + 1}/{num_epochs}")
        print("-" * 40)

        # Train
        train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)

        # Validate
        val_loss, val_acc, class_acc = validate(model, val_loader, criterion, device, metadata)

        epoch_time = time.time() - epoch_start

        # Log results
        print(f"\n  Train Loss: {train_loss:.4f}")
        print(f"  Val Loss:   {val_loss:.4f}")
        print(f"  Val Acc:    {val_acc:.4f}")
        print(f"  Time:       {epoch_time:.1f}s")
        print("  Per-class accuracy:")
        for name, acc in class_acc.items():
            print(f"    {name}: {acc:.4f}")

        # Save history
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': val_loss,
                'val_acc': val_acc,
                'metadata': metadata,
                'config': {
                    'cluster_id': cluster_id,
                    'huc_id': huc_id,
                    'base_filters': base_filters,
                    'learning_rate': learning_rate,
                }
            }, output_dir / "best_model.pth")
            print("  [Saved new best model]")

    # === SAVE FINAL MODEL AND HISTORY ===
    torch.save({
        'epoch': num_epochs,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'val_loss': val_loss,
        'val_acc': val_acc,
        'metadata': metadata,
        'config': {
            'cluster_id': cluster_id,
            'huc_id': huc_id,
            'base_filters': base_filters,
            'learning_rate': learning_rate,
        }
    }, output_dir / "final_model.pth")

    np.save(output_dir / "training_history.npy", history)

    print("\n" + "=" * 60)
    print("Training complete!")
    print(f"Best validation loss: {best_val_loss:.4f}")
    print(f"Models saved to: {output_dir}")

    return history


# Run training (comment out to prevent execution)
history = main()
# Out:
# Using device: mps
# Loading y_train files for class weight computation...
#   Combined y_train shape: (2636, 128, 128)
#
# Class distribution and weights:
#   Background: 33,912,298 pixels (78.52%) -> weight: 1.00
#   EMW: 2,082,479 pixels (4.82%) -> weight: 16.28
#   FSW: 3,325,393 pixels (7.70%) -> weight: 10.20
#   SSW: 2,249,368 pixels (5.21%) -> weight: 15.08
#   OWW: 1,618,686 pixels (3.75%) -> weight: 20.95
#
# Initializing model...
# Total parameters: 7,768,421
#
# Starting training...
# ============================================================
#
# Epoch 1/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.4465
#     Batch 20/264, Loss: 1.4713
#     Batch 30/264, Loss: 1.3839
#     Batch 40/264, Loss: 1.4409
#     Batch 50/264, Loss: 1.4343
#     Batch 60/264, Loss: 1.3913
#     Batch 70/264, Loss: 1.3936
#     Batch 80/264, Loss: 1.7648
#     Batch 90/264, Loss: 1.2766
#     Batch 100/264, Loss: 0.9949
#     Batch 110/264, Loss: 1.2659
#     Batch 120/264, Loss: 1.3554
#     Batch 130/264, Loss: 1.1426
#     Batch 140/264, Loss: 1.4044
#     Batch 150/264, Loss: 1.1665
#     Batch 160/264, Loss: 1.2228
#     Batch 170/264, Loss: 1.5168
#     Batch 180/264, Loss: 1.1669
#     Batch 190/264, Loss: 1.4533
#     Batch 200/264, Loss: 1.8110
#     Batch 210/264, Loss: 1.0661
#     Batch 220/264, Loss: 1.1188
#     Batch 230/264, Loss: 1.0225
#     Batch 240/264, Loss: 1.0698
#     Batch 250/264, Loss: 1.0010
#     Batch 260/264, Loss: 1.0478
#
#   Train Loss: 1.3083
#   Val Loss:   1.2382
#   Val Acc:    0.5414
#   Time:       19.0s
#   Per-class accuracy:
#     Background: 0.5621
#     EMW: 0.1641
#     FSW: 0.6220
#     SSW: 0.3947
#     OWW: 0.7051
#   [Saved new best model]
#
# Epoch 2/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.1260
#     Batch 20/264, Loss: 0.9071
#     Batch 30/264, Loss: 1.2944
#     Batch 40/264, Loss: 1.1686
#     Batch 50/264, Loss: 1.2469
#     Batch 60/264, Loss: 0.9944
#     Batch 70/264, Loss: 1.0599
#     Batch 80/264, Loss: 1.2142
#     Batch 90/264, Loss: 1.3978
#     Batch 100/264, Loss: 1.0569
#     Batch 110/264, Loss: 1.2829
#     Batch 120/264, Loss: 1.0358
#     Batch 130/264, Loss: 1.4737
#     Batch 140/264, Loss: 1.2679
#     Batch 150/264, Loss: 1.1695
#     Batch 160/264, Loss: 1.1845
#     Batch 170/264, Loss: 0.8296
#     Batch 180/264, Loss: 0.9698
#     Batch 190/264, Loss: 1.0025
#     Batch 200/264, Loss: 1.5921
#     Batch 210/264, Loss: 1.1560
#     Batch 220/264, Loss: 1.1866
#     Batch 230/264, Loss: 1.2588
#     Batch 240/264, Loss: 1.1336
#     Batch 250/264, Loss: 0.8313
#     Batch 260/264, Loss: 1.1095
#
#   Train Loss: 1.2099
#   Val Loss:   1.2045
#   Val Acc:    0.5608
#   Time:       19.3s
#   Per-class accuracy:
#     Background: 0.5750
#     EMW: 0.5075
#     FSW: 0.6792
#     SSW: 0.0518
#     OWW: 0.7050
#   [Saved new best model]
#
# Epoch 3/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.0901
#     Batch 20/264, Loss: 0.9857
#     Batch 30/264, Loss: 1.0663
#     Batch 40/264, Loss: 1.2519
#     Batch 50/264, Loss: 0.9078
#     Batch 60/264, Loss: 1.6407
#     Batch 70/264, Loss: 1.5652
#     Batch 80/264, Loss: 1.1453
#     Batch 90/264, Loss: 1.0347
#     Batch 100/264, Loss: 0.9600
#     Batch 110/264, Loss: 0.8985
#     Batch 120/264, Loss: 0.9825
#     Batch 130/264, Loss: 1.2506
#     Batch 140/264, Loss: 1.0225
#     Batch 150/264, Loss: 1.4263
#     Batch 160/264, Loss: 1.3049
#     Batch 170/264, Loss: 0.9526
#     Batch 180/264, Loss: 1.2208
#     Batch 190/264, Loss: 1.2624
#     Batch 200/264, Loss: 1.3124
#     Batch 210/264, Loss: 0.8899
#     Batch 220/264, Loss: 1.4226
#     Batch 230/264, Loss: 1.0165
#     Batch 240/264, Loss: 1.3852
#     Batch 250/264, Loss: 1.1671
#     Batch 260/264, Loss: 1.2091
#
#   Train Loss: 1.1637
#   Val Loss:   1.1841
#   Val Acc:    0.5673
#   Time:       20.2s
#   Per-class accuracy:
#     Background: 0.5868
#     EMW: 0.5068
#     FSW: 0.5248
#     SSW: 0.2395
#     OWW: 0.7583
#   [Saved new best model]
#
# Epoch 4/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.3229
#     Batch 20/264, Loss: 1.5548
#     Batch 30/264, Loss: 0.9692
#     Batch 40/264, Loss: 1.1751
#     Batch 50/264, Loss: 1.1198
#     Batch 60/264, Loss: 1.0946
#     Batch 70/264, Loss: 1.3835
#     Batch 80/264, Loss: 1.2125
#     Batch 90/264, Loss: 0.8290
#     Batch 100/264, Loss: 0.8986
#     Batch 110/264, Loss: 1.2941
#     Batch 120/264, Loss: 0.9566
#     Batch 130/264, Loss: 0.9503
#     Batch 140/264, Loss: 1.1778
#     Batch 150/264, Loss: 1.3994
#     Batch 160/264, Loss: 1.2893
#     Batch 170/264, Loss: 1.0746
#     Batch 180/264, Loss: 1.1130
#     Batch 190/264, Loss: 0.8793
#     Batch 200/264, Loss: 1.0751
#     Batch 210/264, Loss: 1.7406
#     Batch 220/264, Loss: 1.2861
#     Batch 230/264, Loss: 0.9631
#     Batch 240/264, Loss: 1.0389
#     Batch 250/264, Loss: 1.0730
#     Batch 260/264, Loss: 1.2268
#
#   Train Loss: 1.1661
#   Val Loss:   1.1918
#   Val Acc:    0.5999
#   Time:       20.4s
#   Per-class accuracy:
#     Background: 0.6306
#     EMW: 0.5598
#     FSW: 0.5707
#     SSW: 0.0904
#     OWW: 0.7379
#
# Epoch 5/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.8890
#     Batch 20/264, Loss: 1.1451
#     Batch 30/264, Loss: 1.0445
#     Batch 40/264, Loss: 1.2467
#     Batch 50/264, Loss: 1.1046
#     Batch 60/264, Loss: 0.8691
#     Batch 70/264, Loss: 1.2436
#     Batch 80/264, Loss: 1.1479
#     Batch 90/264, Loss: 1.2989
#     Batch 100/264, Loss: 1.5308
#     Batch 110/264, Loss: 1.3821
#     Batch 120/264, Loss: 1.0184
#     Batch 130/264, Loss: 1.1580
#     Batch 140/264, Loss: 1.2896
#     Batch 150/264, Loss: 1.2611
#     Batch 160/264, Loss: 1.0714
#     Batch 170/264, Loss: 1.2263
#     Batch 180/264, Loss: 1.3415
#     Batch 190/264, Loss: 0.7416
#     Batch 200/264, Loss: 1.0022
#     Batch 210/264, Loss: 1.7161
#     Batch 220/264, Loss: 1.2029
#     Batch 230/264, Loss: 1.0291
#     Batch 240/264, Loss: 1.5380
#     Batch 250/264, Loss: 1.3786
#     Batch 260/264, Loss: 1.0994
#
#   Train Loss: 1.1529
#   Val Loss:   1.1840
#   Val Acc:    0.5930
#   Time:       20.7s
#   Per-class accuracy:
#     Background: 0.6171
#     EMW: 0.5202
#     FSW: 0.6566
#     SSW: 0.1011
#     OWW: 0.6850
#   [Saved new best model]
#
# Epoch 6/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.3970
#     Batch 20/264, Loss: 1.0745
#     Batch 30/264, Loss: 1.2567
#     Batch 40/264, Loss: 0.9323
#     Batch 50/264, Loss: 1.0543
#     Batch 60/264, Loss: 1.0901
#     Batch 70/264, Loss: 1.1766
#     Batch 80/264, Loss: 0.9397
#     Batch 90/264, Loss: 1.5777
#     Batch 100/264, Loss: 1.0046
#     Batch 110/264, Loss: 1.0644
#     Batch 120/264, Loss: 1.8552
#     Batch 130/264, Loss: 1.2105
#     Batch 140/264, Loss: 0.9416
#     Batch 150/264, Loss: 0.9796
#     Batch 160/264, Loss: 1.7076
#     Batch 170/264, Loss: 1.2248
#     Batch 180/264, Loss: 0.9052
#     Batch 190/264, Loss: 1.0117
#     Batch 200/264, Loss: 1.2044
#     Batch 210/264, Loss: 1.1756
#     Batch 220/264, Loss: 0.7183
#     Batch 230/264, Loss: 1.2670
#     Batch 240/264, Loss: 0.8545
#     Batch 250/264, Loss: 0.7566
#     Batch 260/264, Loss: 1.2910
#
#   Train Loss: 1.1253
#   Val Loss:   1.1535
#   Val Acc:    0.6439
#   Time:       20.5s
#   Per-class accuracy:
#     Background: 0.6947
#     EMW: 0.4022
#     FSW: 0.4911
#     SSW: 0.3053
#     OWW: 0.7760
#   [Saved new best model]
#
# Epoch 7/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.5279
#     Batch 20/264, Loss: 1.2449
#     Batch 30/264, Loss: 0.8773
#     Batch 40/264, Loss: 0.9167
#     Batch 50/264, Loss: 0.8009
#     Batch 60/264, Loss: 1.1084
#     Batch 70/264, Loss: 1.1776
#     Batch 80/264, Loss: 0.9749
#     Batch 90/264, Loss: 1.1225
#     Batch 100/264, Loss: 0.9543
#     Batch 110/264, Loss: 1.1176
#     Batch 120/264, Loss: 1.0368
#     Batch 130/264, Loss: 1.0056
#     Batch 140/264, Loss: 0.9469
#     Batch 150/264, Loss: 1.6336
#     Batch 160/264, Loss: 0.8203
#     Batch 170/264, Loss: 1.5231
#     Batch 180/264, Loss: 0.9213
#     Batch 190/264, Loss: 1.4440
#     Batch 200/264, Loss: 0.9700
#     Batch 210/264, Loss: 0.9397
#     Batch 220/264, Loss: 1.3821
#     Batch 230/264, Loss: 0.9629
#     Batch 240/264, Loss: 1.2631
#     Batch 250/264, Loss: 1.2722
#     Batch 260/264, Loss: 0.9827
#
#   Train Loss: 1.1364
#   Val Loss:   1.1597
#   Val Acc:    0.5583
#   Time:       20.2s
#   Per-class accuracy:
#     Background: 0.5717
#     EMW: 0.5367
#     FSW: 0.5408
#     SSW: 0.2349
#     OWW: 0.7455
#
# Epoch 8/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.2230
#     Batch 20/264, Loss: 0.9938
#     Batch 30/264, Loss: 0.8389
#     Batch 40/264, Loss: 1.1301
#     Batch 50/264, Loss: 1.0822
#     Batch 60/264, Loss: 1.2552
#     Batch 70/264, Loss: 0.9181
#     Batch 80/264, Loss: 1.2114
#     Batch 90/264, Loss: 0.9324
#     Batch 100/264, Loss: 1.4624
#     Batch 110/264, Loss: 1.0997
#     Batch 120/264, Loss: 1.4670
#     Batch 130/264, Loss: 1.2614
#     Batch 140/264, Loss: 1.0297
#     Batch 150/264, Loss: 1.5596
#     Batch 160/264, Loss: 1.6629
#     Batch 170/264, Loss: 0.9751
#     Batch 180/264, Loss: 1.1352
#     Batch 190/264, Loss: 1.0683
#     Batch 200/264, Loss: 1.4663
#     Batch 210/264, Loss: 1.0085
#     Batch 220/264, Loss: 1.2755
#     Batch 230/264, Loss: 0.8425
#     Batch 240/264, Loss: 1.4856
#     Batch 250/264, Loss: 0.9469
#     Batch 260/264, Loss: 0.9657
#
#   Train Loss: 1.1177
#   Val Loss:   1.1746
#   Val Acc:    0.6663
#   Time:       20.5s
#   Per-class accuracy:
#     Background: 0.7255
#     EMW: 0.4445
#     FSW: 0.5426
#     SSW: 0.1685
#     OWW: 0.7369
#
# Epoch 9/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.0754
#     Batch 20/264, Loss: 1.1357
#     Batch 30/264, Loss: 0.9228
#     Batch 40/264, Loss: 1.0827
#     Batch 50/264, Loss: 0.7751
#     Batch 60/264, Loss: 1.0443
#     Batch 70/264, Loss: 1.3024
#     Batch 80/264, Loss: 0.8403
#     Batch 90/264, Loss: 1.1057
#     Batch 100/264, Loss: 0.7166
#     Batch 110/264, Loss: 1.1236
#     Batch 120/264, Loss: 0.9895
#     Batch 130/264, Loss: 1.0819
#     Batch 140/264, Loss: 1.0303
#     Batch 150/264, Loss: 1.0353
#     Batch 160/264, Loss: 1.0432
#     Batch 170/264, Loss: 1.0150
#     Batch 180/264, Loss: 1.1721
#     Batch 190/264, Loss: 0.9148
#     Batch 200/264, Loss: 1.5325
#     Batch 210/264, Loss: 1.0389
#     Batch 220/264, Loss: 1.1259
#     Batch 230/264, Loss: 1.2286
#     Batch 240/264, Loss: 0.9234
#     Batch 250/264, Loss: 0.9010
#     Batch 260/264, Loss: 1.2906
#
#   Train Loss: 1.1139
#   Val Loss:   1.1757
#   Val Acc:    0.5362
#   Time:       20.3s
#   Per-class accuracy:
#     Background: 0.5341
#     EMW: 0.3515
#     FSW: 0.7621
#     SSW: 0.1745
#     OWW: 0.7725
#
# Epoch 10/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.9861
#     Batch 20/264, Loss: 1.1977
#     Batch 30/264, Loss: 1.4931
#     Batch 40/264, Loss: 0.9228
#     Batch 50/264, Loss: 1.2985
#     Batch 60/264, Loss: 1.2081
#     Batch 70/264, Loss: 0.8537
#     Batch 80/264, Loss: 0.9512
#     Batch 90/264, Loss: 0.9454
#     Batch 100/264, Loss: 1.3035
#     Batch 110/264, Loss: 1.0064
#     Batch 120/264, Loss: 0.7758
#     Batch 130/264, Loss: 1.4713
#     Batch 140/264, Loss: 0.7569
#     Batch 150/264, Loss: 1.1592
#     Batch 160/264, Loss: 1.5700
#     Batch 170/264, Loss: 0.9122
#     Batch 180/264, Loss: 1.0042
#     Batch 190/264, Loss: 1.4114
#     Batch 200/264, Loss: 0.9209
#     Batch 210/264, Loss: 1.3596
#     Batch 220/264, Loss: 1.0261
#     Batch 230/264, Loss: 1.1973
#     Batch 240/264, Loss: 0.8998
#     Batch 250/264, Loss: 1.2535
#     Batch 260/264, Loss: 1.2739
#
#   Train Loss: 1.1080
#   Val Loss:   1.1526
#   Val Acc:    0.6614
#   Time:       20.0s
#   Per-class accuracy:
#     Background: 0.7190
#     EMW: 0.4202
#     FSW: 0.5161
#     SSW: 0.2610
#     OWW: 0.7244
#   [Saved new best model]
#
# Epoch 11/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.0024
#     Batch 20/264, Loss: 1.2695
#     Batch 30/264, Loss: 0.9791
#     Batch 40/264, Loss: 0.9878
#     Batch 50/264, Loss: 0.6422
#     Batch 60/264, Loss: 1.2064
#     Batch 70/264, Loss: 1.2735
#     Batch 80/264, Loss: 0.8147
#     Batch 90/264, Loss: 0.9495
#     Batch 100/264, Loss: 1.5068
#     Batch 110/264, Loss: 1.1857
#     Batch 120/264, Loss: 0.9477
#     Batch 130/264, Loss: 1.6884
#     Batch 140/264, Loss: 1.0679
#     Batch 150/264, Loss: 1.4491
#     Batch 160/264, Loss: 0.8996
#     Batch 170/264, Loss: 0.8828
#     Batch 180/264, Loss: 0.9206
#     Batch 190/264, Loss: 1.0991
#     Batch 200/264, Loss: 0.6665
#     Batch 210/264, Loss: 1.3599
#     Batch 220/264, Loss: 0.9474
#     Batch 230/264, Loss: 1.1409
#     Batch 240/264, Loss: 1.1998
#     Batch 250/264, Loss: 1.3291
#     Batch 260/264, Loss: 1.3520
#
#   Train Loss: 1.0983
#   Val Loss:   1.1228
#   Val Acc:    0.5685
#   Time:       20.0s
#   Per-class accuracy:
#     Background: 0.5748
#     EMW: 0.5108
#     FSW: 0.6965
#     SSW: 0.0989
#     OWW: 0.7974
#   [Saved new best model]
#
# Epoch 12/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.6038
#     Batch 20/264, Loss: 0.9231
#     Batch 30/264, Loss: 0.7765
#     Batch 40/264, Loss: 0.9876
#     Batch 50/264, Loss: 1.0727
#     Batch 60/264, Loss: 0.9584
#     Batch 70/264, Loss: 1.0576
#     Batch 80/264, Loss: 1.0093
#     Batch 90/264, Loss: 0.9099
#     Batch 100/264, Loss: 0.8726
#     Batch 110/264, Loss: 0.8086
#     Batch 120/264, Loss: 1.0379
#     Batch 130/264, Loss: 1.2116
#     Batch 140/264, Loss: 0.8795
#     Batch 150/264, Loss: 0.9645
#     Batch 160/264, Loss: 1.3904
#     Batch 170/264, Loss: 1.3165
#     Batch 180/264, Loss: 1.2781
#     Batch 190/264, Loss: 1.0070
#     Batch 200/264, Loss: 1.4869
#     Batch 210/264, Loss: 1.3022
#     Batch 220/264, Loss: 0.7469
#     Batch 230/264, Loss: 1.6717
#     Batch 240/264, Loss: 1.3551
#     Batch 250/264, Loss: 1.2273
#     Batch 260/264, Loss: 0.7247
#
#   Train Loss: 1.0782
#   Val Loss:   1.1152
#   Val Acc:    0.5782
#   Time:       20.1s
#   Per-class accuracy:
#     Background: 0.5932
#     EMW: 0.5647
#     FSW: 0.5535
#     SSW: 0.1853
#     OWW: 0.8187
#   [Saved new best model]
#
# Epoch 13/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.9942
#     Batch 20/264, Loss: 1.0418
#     Batch 30/264, Loss: 0.9708
#     Batch 40/264, Loss: 1.0856
#     Batch 50/264, Loss: 0.8667
#     Batch 60/264, Loss: 1.6678
#     Batch 70/264, Loss: 1.0087
#     Batch 80/264, Loss: 0.9944
#     Batch 90/264, Loss: 0.8035
#     Batch 100/264, Loss: 0.8087
#     Batch 110/264, Loss: 1.2880
#     Batch 120/264, Loss: 0.8144
#     Batch 130/264, Loss: 1.1658
#     Batch 140/264, Loss: 0.8923
#     Batch 150/264, Loss: 0.7696
#     Batch 160/264, Loss: 0.9639
#     Batch 170/264, Loss: 1.6092
#     Batch 180/264, Loss: 1.1681
#     Batch 190/264, Loss: 1.3257
#     Batch 200/264, Loss: 0.9326
#     Batch 210/264, Loss: 1.2261
#     Batch 220/264, Loss: 1.2450
#     Batch 230/264, Loss: 1.2839
#     Batch 240/264, Loss: 1.1460
#     Batch 250/264, Loss: 1.3014
#     Batch 260/264, Loss: 1.0079
#
#   Train Loss: 1.0880
#   Val Loss:   1.1203
#   Val Acc:    0.6065
#   Time:       19.9s
#   Per-class accuracy:
#     Background: 0.6368
#     EMW: 0.5071
#     FSW: 0.4985
#     SSW: 0.3216
#     OWW: 0.7478
#
# Epoch 14/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.9117
#     Batch 20/264, Loss: 0.6794
#     Batch 30/264, Loss: 0.6220
#     Batch 40/264, Loss: 1.1014
#     Batch 50/264, Loss: 1.7978
#     Batch 60/264, Loss: 1.4736
#     Batch 70/264, Loss: 1.1182
#     Batch 80/264, Loss: 1.2258
#     Batch 90/264, Loss: 0.8954
#     Batch 100/264, Loss: 1.0710
#     Batch 110/264, Loss: 1.5706
#     Batch 120/264, Loss: 1.2843
#     Batch 130/264, Loss: 1.4500
#     Batch 140/264, Loss: 0.9963
#     Batch 150/264, Loss: 0.7963
#     Batch 160/264, Loss: 1.4665
#     Batch 170/264, Loss: 1.1691
#     Batch 180/264, Loss: 1.2624
#     Batch 190/264, Loss: 0.9992
#     Batch 200/264, Loss: 0.8648
#     Batch 210/264, Loss: 1.0035
#     Batch 220/264, Loss: 1.0147
#     Batch 230/264, Loss: 1.2485
#     Batch 240/264, Loss: 0.8389
#     Batch 250/264, Loss: 1.1159
#     Batch 260/264, Loss: 1.0144
#
#   Train Loss: 1.0779
#   Val Loss:   1.1428
#   Val Acc:    0.5215
#   Time:       20.1s
#   Per-class accuracy:
#     Background: 0.5216
#     EMW: 0.5705
#     FSW: 0.4716
#     SSW: 0.3466
#     OWW: 0.7467
#
# Epoch 15/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.2507
#     Batch 20/264, Loss: 1.4334
#     Batch 30/264, Loss: 1.0209
#     Batch 40/264, Loss: 0.9110
#     Batch 50/264, Loss: 1.0953
#     Batch 60/264, Loss: 0.8674
#     Batch 70/264, Loss: 0.6108
#     Batch 80/264, Loss: 1.5188
#     Batch 90/264, Loss: 0.9560
#     Batch 100/264, Loss: 0.7457
#     Batch 110/264, Loss: 1.7342
#     Batch 120/264, Loss: 1.1182
#     Batch 130/264, Loss: 1.4668
#     Batch 140/264, Loss: 1.1126
#     Batch 150/264, Loss: 1.1684
#     Batch 160/264, Loss: 0.8001
#     Batch 170/264, Loss: 0.8598
#     Batch 180/264, Loss: 1.1700
#     Batch 190/264, Loss: 0.9485
#     Batch 200/264, Loss: 1.0690
#     Batch 210/264, Loss: 1.1813
#     Batch 220/264, Loss: 0.9495
#     Batch 230/264, Loss: 0.8866
#     Batch 240/264, Loss: 1.1739
#     Batch 250/264, Loss: 1.3541
#     Batch 260/264, Loss: 1.2686
#
#   Train Loss: 1.0667
#   Val Loss:   1.1301
#   Val Acc:    0.5996
#   Time:       20.1s
#   Per-class accuracy:
#     Background: 0.6343
#     EMW: 0.4721
#     FSW: 0.4198
#     SSW: 0.2839
#     OWW: 0.8850
#
# Epoch 16/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.9254
#     Batch 20/264, Loss: 0.8180
#     Batch 30/264, Loss: 0.9614
#     Batch 40/264, Loss: 0.9570
#     Batch 50/264, Loss: 0.9743
#     Batch 60/264, Loss: 1.1451
#     Batch 70/264, Loss: 1.1493
#     Batch 80/264, Loss: 1.0288
#     Batch 90/264, Loss: 1.1601
#     Batch 100/264, Loss: 0.8376
#     Batch 110/264, Loss: 0.6570
#     Batch 120/264, Loss: 1.0358
#     Batch 130/264, Loss: 1.4292
#     Batch 140/264, Loss: 0.9647
#     Batch 150/264, Loss: 1.5402
#     Batch 160/264, Loss: 0.9281
#     Batch 170/264, Loss: 0.8302
#     Batch 180/264, Loss: 1.0977
#     Batch 190/264, Loss: 1.0350
#     Batch 200/264, Loss: 0.9795
#     Batch 210/264, Loss: 0.9020
#     Batch 220/264, Loss: 0.8684
#     Batch 230/264, Loss: 0.7827
#     Batch 240/264, Loss: 1.0353
#     Batch 250/264, Loss: 1.0972
#     Batch 260/264, Loss: 0.9593
#
#   Train Loss: 1.0600
#   Val Loss:   1.0956
#   Val Acc:    0.6019
#   Time:       19.8s
#   Per-class accuracy:
#     Background: 0.6225
#     EMW: 0.4680
#     FSW: 0.6042
#     SSW: 0.2474
#     OWW: 0.8161
#   [Saved new best model]
#
# Epoch 17/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.6584
#     Batch 20/264, Loss: 1.0966
#     Batch 30/264, Loss: 1.3126
#     Batch 40/264, Loss: 0.9902
#     Batch 50/264, Loss: 1.4510
#     Batch 60/264, Loss: 1.0041
#     Batch 70/264, Loss: 1.4508
#     Batch 80/264, Loss: 0.8575
#     Batch 90/264, Loss: 0.7701
#     Batch 100/264, Loss: 1.1283
#     Batch 110/264, Loss: 1.1955
#     Batch 120/264, Loss: 0.9649
#     Batch 130/264, Loss: 0.9052
#     Batch 140/264, Loss: 1.2510
#     Batch 150/264, Loss: 1.0264
#     Batch 160/264, Loss: 1.1787
#     Batch 170/264, Loss: 0.9600
#     Batch 180/264, Loss: 1.2853
#     Batch 190/264, Loss: 0.9770
#     Batch 200/264, Loss: 1.0887
#     Batch 210/264, Loss: 1.1470
#     Batch 220/264, Loss: 0.6125
#     Batch 230/264, Loss: 1.1161
#     Batch 240/264, Loss: 1.3784
#     Batch 250/264, Loss: 1.0142
#     Batch 260/264, Loss: 1.0614
#
#   Train Loss: 1.0540
#   Val Loss:   1.1186
#   Val Acc:    0.4890
#   Time:       19.5s
#   Per-class accuracy:
#     Background: 0.4687
#     EMW: 0.5629
#     FSW: 0.5735
#     SSW: 0.2515
#     OWW: 0.8360
#
# Epoch 18/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.9458
#     Batch 20/264, Loss: 1.2385
#     Batch 30/264, Loss: 1.1208
#     Batch 40/264, Loss: 0.8968
#     Batch 50/264, Loss: 1.3397
#     Batch 60/264, Loss: 1.1634
#     Batch 70/264, Loss: 1.2744
#     Batch 80/264, Loss: 0.7754
#     Batch 90/264, Loss: 1.1352
#     Batch 100/264, Loss: 0.9839
#     Batch 110/264, Loss: 0.7615
#     Batch 120/264, Loss: 1.2161
#     Batch 130/264, Loss: 0.7244
#     Batch 140/264, Loss: 0.7399
#     Batch 150/264, Loss: 0.8399
#     Batch 160/264, Loss: 1.2717
#     Batch 170/264, Loss: 1.0668
#     Batch 180/264, Loss: 1.4995
#     Batch 190/264, Loss: 1.0491
#     Batch 200/264, Loss: 0.9340
#     Batch 210/264, Loss: 0.8517
#     Batch 220/264, Loss: 0.6546
#     Batch 230/264, Loss: 0.9601
#     Batch 240/264, Loss: 0.8847
#     Batch 250/264, Loss: 0.9467
#     Batch 260/264, Loss: 1.1685
#
#   Train Loss: 1.0445
#   Val Loss:   1.0997
#   Val Acc:    0.5758
#   Time:       19.9s
#   Per-class accuracy:
#     Background: 0.5913
#     EMW: 0.4554
#     FSW: 0.5267
#     SSW: 0.3466
#     OWW: 0.8273
#
# Epoch 19/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.8220
#     Batch 20/264, Loss: 1.0627
#     Batch 30/264, Loss: 0.6630
#     Batch 40/264, Loss: 0.7860
#     Batch 50/264, Loss: 1.0240
#     Batch 60/264, Loss: 1.5232
#     Batch 70/264, Loss: 1.2769
#     Batch 80/264, Loss: 1.5012
#     Batch 90/264, Loss: 0.9311
#     Batch 100/264, Loss: 1.0528
#     Batch 110/264, Loss: 1.1117
#     Batch 120/264, Loss: 0.9533
#     Batch 130/264, Loss: 1.0429
#     Batch 140/264, Loss: 1.0878
#     Batch 150/264, Loss: 0.9328
#     Batch 160/264, Loss: 0.9900
#     Batch 170/264, Loss: 1.0056
#     Batch 180/264, Loss: 1.3978
#     Batch 190/264, Loss: 0.6897
#     Batch 200/264, Loss: 0.9839
#     Batch 210/264, Loss: 0.7588
#     Batch 220/264, Loss: 1.3992
#     Batch 230/264, Loss: 1.0534
#     Batch 240/264, Loss: 1.1477
#     Batch 250/264, Loss: 0.6746
#     Batch 260/264, Loss: 1.0102
#
#   Train Loss: 1.0415
#   Val Loss:   1.1861
#   Val Acc:    0.5961
#   Time:       19.9s
#   Per-class accuracy:
#     Background: 0.6217
#     EMW: 0.2496
#     FSW: 0.6645
#     SSW: 0.3246
#     OWW: 0.7925
#
# Epoch 20/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.8250
#     Batch 20/264, Loss: 0.8580
#     Batch 30/264, Loss: 1.1447
#     Batch 40/264, Loss: 0.8626
#     Batch 50/264, Loss: 0.9211
#     Batch 60/264, Loss: 0.7192
#     Batch 70/264, Loss: 1.4965
#     Batch 80/264, Loss: 1.1238
#     Batch 90/264, Loss: 1.3166
#     Batch 100/264, Loss: 1.0881
#     Batch 110/264, Loss: 0.9240
#     Batch 120/264, Loss: 1.1759
#     Batch 130/264, Loss: 0.6152
#     Batch 140/264, Loss: 0.6571
#     Batch 150/264, Loss: 1.0215
#     Batch 160/264, Loss: 0.8830
#     Batch 170/264, Loss: 0.7688
#     Batch 180/264, Loss: 0.6132
#     Batch 190/264, Loss: 0.7987
#     Batch 200/264, Loss: 1.1889
#     Batch 210/264, Loss: 0.6469
#     Batch 220/264, Loss: 0.8760
#     Batch 230/264, Loss: 0.9092
#     Batch 240/264, Loss: 0.7459
#     Batch 250/264, Loss: 1.0557
#     Batch 260/264, Loss: 1.1968
#
#   Train Loss: 1.0267
#   Val Loss:   1.1459
#   Val Acc:    0.5668
#   Time:       19.7s
#   Per-class accuracy:
#     Background: 0.5700
#     EMW: 0.5431
#     FSW: 0.6687
#     SSW: 0.2137
#     OWW: 0.7259
#
# Epoch 21/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.8587
#     Batch 20/264, Loss: 0.7303
#     Batch 30/264, Loss: 0.9991
#     Batch 40/264, Loss: 1.1673
#     Batch 50/264, Loss: 1.4361
#     Batch 60/264, Loss: 1.0326
#     Batch 70/264, Loss: 1.1064
#     Batch 80/264, Loss: 0.8503
#     Batch 90/264, Loss: 1.3669
#     Batch 100/264, Loss: 0.7649
#     Batch 110/264, Loss: 1.2139
#     Batch 120/264, Loss: 0.7332
#     Batch 130/264, Loss: 1.0384
#     Batch 140/264, Loss: 0.7789
#     Batch 150/264, Loss: 0.8457
#     Batch 160/264, Loss: 1.0238
#     Batch 170/264, Loss: 0.8367
#     Batch 180/264, Loss: 0.8986
#     Batch 190/264, Loss: 0.8745
#     Batch 200/264, Loss: 1.1052
#     Batch 210/264, Loss: 1.3251
#     Batch 220/264, Loss: 1.0956
#     Batch 230/264, Loss: 1.0196
#     Batch 240/264, Loss: 0.7400
#     Batch 250/264, Loss: 1.2990
#     Batch 260/264, Loss: 1.3306
#
#   Train Loss: 1.0261
#   Val Loss:   1.1228
#   Val Acc:    0.5554
#   Time:       19.8s
#   Per-class accuracy:
#     Background: 0.5563
#     EMW: 0.5545
#     FSW: 0.6140
#     SSW: 0.2179
#     OWW: 0.7954
#
# Epoch 22/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.0323
#     Batch 20/264, Loss: 0.8077
#     Batch 30/264, Loss: 0.6210
#     Batch 40/264, Loss: 0.8684
#     Batch 50/264, Loss: 1.0505
#     Batch 60/264, Loss: 0.5810
#     Batch 70/264, Loss: 0.6839
#     Batch 80/264, Loss: 1.1667
#     Batch 90/264, Loss: 1.0346
#     Batch 100/264, Loss: 0.9562
#     Batch 110/264, Loss: 0.9069
#     Batch 120/264, Loss: 0.9581
#     Batch 130/264, Loss: 1.6214
#     Batch 140/264, Loss: 0.9765
#     Batch 150/264, Loss: 1.1799
#     Batch 160/264, Loss: 0.9618
#     Batch 170/264, Loss: 0.8855
#     Batch 180/264, Loss: 0.7352
#     Batch 190/264, Loss: 0.9305
#     Batch 200/264, Loss: 1.1671
#     Batch 210/264, Loss: 1.5333
#     Batch 220/264, Loss: 1.0075
#     Batch 230/264, Loss: 1.0925
#     Batch 240/264, Loss: 1.0830
#     Batch 250/264, Loss: 1.0287
#     Batch 260/264, Loss: 0.7735
#
#   Train Loss: 1.0256
#   Val Loss:   1.1131
#   Val Acc:    0.6675
#   Time:       19.8s
#   Per-class accuracy:
#     Background: 0.7196
#     EMW: 0.5055
#     FSW: 0.5293
#     SSW: 0.2398
#     OWW: 0.7305
#
# Epoch 23/25
# ----------------------------------------
#     Batch 10/264, Loss: 1.0560
#     Batch 20/264, Loss: 1.0069
#     Batch 30/264, Loss: 1.0960
#     Batch 40/264, Loss: 0.9155
#     Batch 50/264, Loss: 0.6332
#     Batch 60/264, Loss: 1.1089
#     Batch 70/264, Loss: 0.7419
#     Batch 80/264, Loss: 1.2879
#     Batch 90/264, Loss: 1.0455
#     Batch 100/264, Loss: 1.2051
#     Batch 110/264, Loss: 1.0140
#     Batch 120/264, Loss: 0.8931
#     Batch 130/264, Loss: 0.8818
#     Batch 140/264, Loss: 1.4170
#     Batch 150/264, Loss: 0.7650
#     Batch 160/264, Loss: 0.8019
#     Batch 170/264, Loss: 1.1937
#     Batch 180/264, Loss: 0.7304
#     Batch 190/264, Loss: 0.7791
#     Batch 200/264, Loss: 0.9715
#     Batch 210/264, Loss: 0.8638
#     Batch 220/264, Loss: 0.4166
#     Batch 230/264, Loss: 0.9154
#     Batch 240/264, Loss: 1.2221
#     Batch 250/264, Loss: 0.8715
#     Batch 260/264, Loss: 1.5210
#
#   Train Loss: 1.0248
#   Val Loss:   1.1181
#   Val Acc:    0.5508
#   Time:       20.5s
#   Per-class accuracy:
#     Background: 0.5708
#     EMW: 0.5469
#     FSW: 0.3216
#     SSW: 0.4622
#     OWW: 0.7730
#
# Epoch 24/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.8600
#     Batch 20/264, Loss: 0.7586
#     Batch 30/264, Loss: 0.6576
#     Batch 40/264, Loss: 1.0306
#     Batch 50/264, Loss: 1.0454
#     Batch 60/264, Loss: 1.1260
#     Batch 70/264, Loss: 0.9202
#     Batch 80/264, Loss: 0.9344
#     Batch 90/264, Loss: 1.0817
#     Batch 100/264, Loss: 1.1761
#     Batch 110/264, Loss: 1.4208
#     Batch 120/264, Loss: 1.4358
#     Batch 130/264, Loss: 1.2594
#     Batch 140/264, Loss: 1.4980
#     Batch 150/264, Loss: 1.2266
#     Batch 160/264, Loss: 1.0982
#     Batch 170/264, Loss: 0.9632
#     Batch 180/264, Loss: 0.8443
#     Batch 190/264, Loss: 0.7875
#     Batch 200/264, Loss: 1.1601
#     Batch 210/264, Loss: 0.6680
#     Batch 220/264, Loss: 0.5371
#     Batch 230/264, Loss: 0.8991
#     Batch 240/264, Loss: 1.1558
#     Batch 250/264, Loss: 1.1371
#     Batch 260/264, Loss: 1.0365
#
#   Train Loss: 1.0058
#   Val Loss:   1.1472
#   Val Acc:    0.6827
#   Time:       20.0s
#   Per-class accuracy:
#     Background: 0.7560
#     EMW: 0.3470
#     FSW: 0.3592
#     SSW: 0.5183
#     OWW: 0.7044
#
# Epoch 25/25
# ----------------------------------------
#     Batch 10/264, Loss: 0.9606
#     Batch 20/264, Loss: 0.8931
#     Batch 30/264, Loss: 0.7827
#     Batch 40/264, Loss: 1.0599
#     Batch 50/264, Loss: 0.7442
#     Batch 60/264, Loss: 1.0138
#     Batch 70/264, Loss: 1.0843
#     Batch 80/264, Loss: 0.4955
#     Batch 90/264, Loss: 0.9575
#     Batch 100/264, Loss: 0.8928
#     Batch 110/264, Loss: 1.2557
#     Batch 120/264, Loss: 0.5328
#     Batch 130/264, Loss: 0.8368
#     Batch 140/264, Loss: 1.4374
#     Batch 150/264, Loss: 1.0420
#     Batch 160/264, Loss: 0.6491
#     Batch 170/264, Loss: 0.7900
#     Batch 180/264, Loss: 0.9275
#     Batch 190/264, Loss: 0.8045
#     Batch 200/264, Loss: 0.9051
#     Batch 210/264, Loss: 1.0056
#     Batch 220/264, Loss: 1.2268
#     Batch 230/264, Loss: 1.1068
#     Batch 240/264, Loss: 0.6048
#     Batch 250/264, Loss: 0.9320
#     Batch 260/264, Loss: 0.8650
#
#   Train Loss: 1.0053
#   Val Loss:   1.0683
#   Val Acc:    0.5884
#   Time:       20.0s
#   Per-class accuracy:
#     Background: 0.6068
#     EMW: 0.4948
#     FSW: 0.5004
#     SSW: 0.4259
#     OWW: 0.7562
#   [Saved new best model]
#
# ============================================================
# Training complete!
# Best validation loss: 1.0683
# Models saved to: Models

# %%
# !jupyter nbconvert --to script Python_Code_Analysis/DL_Implement/NYS_06_train.ipynb --TagRemovePreprocessor.remove_cell_tags='{"remove"}'
# Out:
# [NbConvertApp] Converting notebook Python_Code_Analysis/DL_Implement/NYS_06_train.ipynb to script
# [NbConvertApp] Writing 7688 bytes to Python_Code_Analysis/DL_Implement/NYS_06_train.py
